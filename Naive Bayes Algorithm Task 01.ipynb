# %% [markdown]
# # **USA RAINFALL PREDICTION DATASET (2024-2025)**

# %% [markdown]
# **Data Sources :**

# %% [markdown]
# usa_rain_prediction_dataset_2024_2025.csv

# %% [markdown]
# **About DataSet**

# %% [markdown]
# This file contains weather data collected from January 1, 2024, to December 31, 2025, for 20 major US cities. The dataset includes columns such as Temperature, Humidity, Wind Speed, Precipitation, Cloud Cover, Pressure, and the Rain Tomorrow label.

# %% [markdown]
# **IMPORTING LIBRARIRES**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **DATA COLLECTION**

# %%
df = pd.read_csv('/content/drive/MyDrive/DATA SCIENCE/Machine Learning/MACHINE LEARNING ALGORITHMS/NAIVE BAYES ALGORITHM/usa_rain_prediction_dataset_2024_2025.csv')

# %%
df
# Out:
#              Date         Location  Temperature   Humidity  Wind Speed  \
# 0      2024-01-01         New York    87.524795  75.655455   28.379506
# 1      2024-01-02         New York    83.259325  28.712617   12.436433
# 2      2024-01-03         New York    80.943050  64.740043   14.184831
# 3      2024-01-04         New York    78.097552  59.738984   19.444029
# 4      2024-01-05         New York    37.059963  34.766784    3.689661
# ...           ...              ...          ...        ...         ...
# 73095  2025-12-27  Washington D.C.    40.614393  65.099438   28.778327
# 73096  2025-12-28  Washington D.C.    52.641643  30.610525   12.282890
# 73097  2025-12-29  Washington D.C.    56.492591  96.740232    2.894762
# 73098  2025-12-30  Washington D.C.    65.748956  63.900004   24.632400
# 73099  2025-12-31  Washington D.C.    54.648609  80.812021   22.722505
#
#        Precipitation  Cloud Cover     Pressure  Rain Tomorrow
# ...

# %%
df.head()
# Out:
#          Date  Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0  2024-01-01  New York    87.524795  75.655455   28.379506       0.000000
# 1  2024-01-02  New York    83.259325  28.712617   12.436433       0.526995
# 2  2024-01-03  New York    80.943050  64.740043   14.184831       0.916884
# 3  2024-01-04  New York    78.097552  59.738984   19.444029       0.094134
# 4  2024-01-05  New York    37.059963  34.766784    3.689661       1.361272
#
#    Cloud Cover     Pressure  Rain Tomorrow
# 0    69.617966  1026.030278              0
# 1    41.606048   995.962065              0
# 2    77.364763   980.796739              1
# 3    52.541196   979.012163              0
# 4    85.584000  1031.790859              0

# %%
df.shape
# Out:
# (73100, 9)

# %%
df.shape
# Out:
# (73100, 9)

# %%
df.isnull().any()
# Out:
# Date             False
# Location         False
# Temperature      False
# Humidity         False
# Wind Speed       False
# Precipitation    False
# Cloud Cover      False
# Pressure         False
# Rain Tomorrow    False
# dtype: bool

# %%
df = df.drop('Date', axis=1)

# %%
df.head()
# Out:
#    Location  Temperature   Humidity  Wind Speed  Precipitation  Cloud Cover  \
# 0  New York    87.524795  75.655455   28.379506       0.000000    69.617966
# 1  New York    83.259325  28.712617   12.436433       0.526995    41.606048
# 2  New York    80.943050  64.740043   14.184831       0.916884    77.364763
# 3  New York    78.097552  59.738984   19.444029       0.094134    52.541196
# 4  New York    37.059963  34.766784    3.689661       1.361272    85.584000
#
#       Pressure  Rain Tomorrow
# 0  1026.030278              0
# 1   995.962065              0
# 2   980.796739              1
# 3   979.012163              0
# 4  1031.790859              0

# %%
df.shape
# Out:
# (73100, 8)

# %%
df['Location'].value_counts()
# Out:
# Location
# New York           3655
# Los Angeles        3655
# Denver             3655
# Seattle            3655
# San Francisco      3655
# Charlotte          3655
# Indianapolis       3655
# Columbus           3655
# Fort Worth         3655
# Jacksonville       3655
# Austin             3655
# San Jose           3655
# Dallas             3655
# San Diego          3655
# San Antonio        3655
# Philadelphia       3655
# Phoenix            3655
# Houston            3655
# Chicago            3655
# Washington D.C.    3655
# Name: count, dtype: int64

# %%
df['Location'].unique()
# Out:
# array(['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix',
#        'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose',
#        'Austin', 'Jacksonville', 'Fort Worth', 'Columbus', 'Indianapolis',
#        'Charlotte', 'San Francisco', 'Seattle', 'Denver',
#        'Washington D.C.'], dtype=object)

# %%
df['Location'] = df['Location'].replace({'New York': 1, 'Los Angeles': 2, 'Chicago': 3, 'Houston': 4, 'Philadelphia': 5, 'Phoenix': 6, 'San Antonio': 7, 'San Diego': 8, 'Dallas': 9, 'San Jose': 10, 'Austin':11, 'Jacksonville':12, 'Fort Worth':13, 'Columbus':14, 'San Francisco':15, 'Charlotte':16, 'Indianapolis':17, 'Seattle':18, 'Denver':19, 'Washington D.C.':20})
# Out:
# <ipython-input-13-fd361a087679>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Location'] = df['Location'].replace({'New York': 1, 'Los Angeles': 2, 'Chicago': 3, 'Houston': 4, 'Philadelphia': 5, 'Phoenix': 6, 'San Antonio': 7, 'San Diego': 8, 'Dallas': 9, 'San Jose': 10, 'Austin':11, 'Jacksonville':12, 'Fort Worth':13, 'Columbus':14, 'San Francisco':15, 'Charlotte':16, 'Indianapolis':17, 'Seattle':18, 'Denver':19, 'Washington D.C.':20})

# %%
df
# Out:
#        Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0             1    87.524795  75.655455   28.379506       0.000000
# 1             1    83.259325  28.712617   12.436433       0.526995
# 2             1    80.943050  64.740043   14.184831       0.916884
# 3             1    78.097552  59.738984   19.444029       0.094134
# 4             1    37.059963  34.766784    3.689661       1.361272
# ...         ...          ...        ...         ...            ...
# 73095        20    40.614393  65.099438   28.778327       0.000000
# 73096        20    52.641643  30.610525   12.282890       0.871000
# 73097        20    56.492591  96.740232    2.894762       1.191956
# 73098        20    65.748956  63.900004   24.632400       0.483421
# 73099        20    54.648609  80.812021   22.722505       0.151903
#
#        Cloud Cover     Pressure  Rain Tomorrow
# 0        69.617966  1026.030278              0
# 1        41.606048   995.962065              0
# ...

# %%
corr_matrix = df.corr()['Rain Tomorrow']
corr_matrix
# Out:
# Location         0.001425
# Temperature     -0.003593
# Humidity         0.461646
# Wind Speed      -0.011715
# Precipitation    0.489804
# Cloud Cover     -0.003385
# Pressure        -0.002179
# Rain Tomorrow    1.000000
# Name: Rain Tomorrow, dtype: float64

# %%
x = df.drop('Rain Tomorrow', axis = 1)
y = df['Rain Tomorrow']

# %%
x.head()
# Out:
#    Location  Temperature   Humidity  Wind Speed  Precipitation  Cloud Cover  \
# 0         1    87.524795  75.655455   28.379506       0.000000    69.617966
# 1         1    83.259325  28.712617   12.436433       0.526995    41.606048
# 2         1    80.943050  64.740043   14.184831       0.916884    77.364763
# 3         1    78.097552  59.738984   19.444029       0.094134    52.541196
# 4         1    37.059963  34.766784    3.689661       1.361272    85.584000
#
#       Pressure
# 0  1026.030278
# 1   995.962065
# 2   980.796739
# 3   979.012163
# 4  1031.790859

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Rain Tomorrow, dtype: int64

# %% [markdown]
# **DATA EXPLORATION**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
y_train.value_counts()
# Out:
# Rain Tomorrow
# 0    45651
# 1    12829
# Name: count, dtype: int64

# %%
#SMOTE METHODE

from imblearn.over_sampling import SMOTE

sm = SMOTE()

# %%
x_res,y_res = sm.fit_resample(x_train,y_train)

# %%
y_res.value_counts()
# Out:
# Rain Tomorrow
# 0    45651
# 1    45651
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
x_test = sd.fit_transform(x_test)
x_train = sd.transform(x_train)
x_res = sd.fit_transform(x_res)

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)

y_pred = nb.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

score = accuracy_score(y_test,y_pred)

score
# Out:
# 0.908344733242134

# %%
conf_metc = confusion_matrix(y_test,y_pred)
conf_metc
# Out:
# array([[11267,    70],
#        [ 1270,  2013]])

# %%
from sklearn.metrics import mean_squared_error, precision_score, recall_score

msc = mean_squared_error(y_test,y_pred)
print('MSC : ',msc)
# Out:
# MSC :  0.09165526675786594

# %%
precision = precision_score(y_test,y_pred, average = 'binary')
print('Precision : %3f'% precision)
# Out:
# Precision : 0.966395

# %%
recall = recall_score(y_test,y_pred, average = 'binary')
print('Recall : %3f'% recall)
# Out:
# Recall : 0.613159

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
labels = ['Yes','No']
cm = confusion_matrix(y_test,y_pred)

# %%
cmd = ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()

# %%
y_pred = nb.predict([[20,22.059963,23.766784,4.689661,1.361272,85.584000,1031.790859]])
y_pred
# Out:
# array([0])

# %%
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9752393980848153

# %%
y_pred = model.predict([[11,37.059963,30.766784,2.689661,2.361272,86.584000,980.790859]])
y_pred
# Out:
# array([1])

# %% [markdown]
# **INSIGHTS**

# %% [markdown]
# **Strongest Relationships:** The strongest predictors for rain tomorrow are **Humidity** and **Precipitation**, both showing moderate positive correlations.
#
# **Weakest Relationships:** The other variables (**Location**, **Temperature**, **Wind Speed**, **Cloud Cover**, **Pressure**) show very weak correlations, suggesting they have little to no influence on predicting rain tomorrow.
